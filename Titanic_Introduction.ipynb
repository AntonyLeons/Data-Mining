# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonyLeons/Data-Mining/blob/master/Titanic_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ensure Python > 3.6

# %% [markdown]
# # Importing
# Import pandas library, using an alias of pd. (Saves a lot of typing)

# %%
import pandas as pd
import seaborn as sns
# #pandas.someMethod()
import numpy as np
import random
# %matplotlib notebook
# from google.colab import files

# uploaded = files.upload()

# for fn in uploaded.keys():
#   print('User uploaded file "{name}" with length {length} bytes'.format(
#       name=fn, length=len(uploaded[fn])))

# %% [markdown]
# # Loading Data
# Our data exists as a standard csv file, with headings to columns.
# Use the read_csv function of the pandas library, providing it the file to load.
# This is then loaded into a DataFrame Object. Which lets us manipulate the data easily.

# %%
data = pd.read_csv('train.csv') # .. = Get our parent folder.
data.set_index('PassengerId')
# Out:
#              Survived  Pclass  ... Cabin Embarked
# PassengerId                    ...
# 1                   0       3  ...   NaN        S
# 2                   1       1  ...   C85        C
# 3                   1       3  ...   NaN        S
# 4                   1       1  ...  C123        S
# 5                   0       3  ...   NaN        S
# ...               ...     ...  ...   ...      ...
# 887                 0       2  ...   NaN        S
# 888                 1       1  ...   B42        S
# 889                 0       3  ...   NaN        S
# 890                 1       1  ...  C148        C
# 891                 0       3  ...   NaN        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# # Simple Statistics
# 'describe' will run some simple statistical analysis on the data loaded, for each attribute.
# mean, min, max, standard deviation. Inter-quartile ranges.

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %% [markdown]
# ## Head
# Head allows us to take the 'top' of the dataframe object. Has a default value, but can specify an integer.

# %%
data.head(15)
# Out:
#     PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0             1         0       3  ...   7.2500   NaN         S
# 1             2         1       1  ...  71.2833   C85         C
# 2             3         1       3  ...   7.9250   NaN         S
# 3             4         1       1  ...  53.1000  C123         S
# 4             5         0       3  ...   8.0500   NaN         S
# 5             6         0       3  ...   8.4583   NaN         Q
# 6             7         0       1  ...  51.8625   E46         S
# 7             8         0       3  ...  21.0750   NaN         S
# 8             9         1       3  ...  11.1333   NaN         S
# 9            10         1       2  ...  30.0708   NaN         C
# 10           11         1       3  ...  16.7000    G6         S
# 11           12         1       1  ...  26.5500  C103         S
# 12           13         0       3  ...   8.0500   NaN         S
# 13           14         0       3  ...  31.2750   NaN         S
# ...

# %%
# Methods and Attributes of a DataFrame are available here:
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html
# Documentation is important!

subData = data.head(15)
number_of_headings = 0

for heading in subData.columns: # Similar to collections in C#.
    print(heading)
    number_of_headings += 1

print(f"Number of headings: {number_of_headings}") # f-strings
print("Number of headings(2): " + str(number_of_headings)) # String concatenation

print("\n\n\n") # Printing newlines.

# Iterate over some collection.
for entry in subData.values:
    print(entry)
# Out:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked
# Number of headings: 12
# Number of headings(2): 12
#
#
#
#
# [1 0 3 'Braund, Mr. Owen Harris' 'male' 22.0 1 0 'A/5 21171' 7.25 nan 'S']
# [2 1 1 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)' 'female' 38.0
#  1 0 'PC 17599' 71.2833 'C85' 'C']
# [3 1 3 'Heikkinen, Miss. Laina' 'female' 26.0 0 0 'STON/O2. 3101282' 7.925
#  nan 'S']
# [4 1 1 'Futrelle, Mrs. Jacques Heath (Lily May Peel)' 'female' 35.0 1 0
#  '113803' 53.1 'C123' 'S']
# [5 0 3 'Allen, Mr. William Henry' 'male' 35.0 0 0 '373450' 8.05 nan 'S']
# [6 0 3 'Moran, Mr. James' 'male' nan 0 0 '330877' 8.4583 nan 'Q']
# [7 0 1 'McCarthy, Mr. Timothy J' 'male' 54.0 0 0 '17463' 51.8625 'E46' 'S']
# [8 0 3 'Palsson, Master. Gosta Leonard' 'male' 2.0 3 1 '349909' 21.075 nan
#  'S']
# [9 1 3 'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)' 'female' 27.0 0
#  2 '347742' 11.1333 nan 'S']
# ...

# %% [markdown]
# # Complex querying
# DataFrames are very versatile, allowing you to select only attributes you want.
# The syntax for this is similar to array indexing. However, we pass it a string-array of columns we want to use.
# Sample can be used to randomly select data entries from our full data.

# %%
data[['PassengerId', 'Survived']].sample(50)
# Out:
#      PassengerId  Survived
# 130          131         0
# 383          384         1
# 269          270         1
# 323          324         1
# 525          526         0
# 122          123         0
# 704          705         0
# 571          572         1
# 789          790         0
# 60            61         0
# 265          266         0
# 347          348         1
# 114          115         0
# 579          580         1
# 652          653         0
# 501          502         0
# 523          524         1
# 41            42         0
# 636          637         0
# 274          275         1
# 840          841         0
# 716          717         1
# 862          863         1
# 315          316         1
# 507          508         1
# 656          657         0
# 208          209         1
# 140          141         0
# 506          507         1
# 50            51         0
# 412          413         1
# 20            21         0
# 800          801         0
# ...

# %% [markdown]
# ### Useful for figuring out number of patterns for useful attributes.
# This is how I arrived at 0.42 for min age in the lecture slides, and the maximum age.

# %%
data[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']].describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
sid_values= data['PassengerId']
nid_values = np.asarray(sid_values)
id_values = pd.Series(nid_values)
id_values.describe()
# Out:
# count    891.000000
# mean     446.000000
# std      257.353842
# min        1.000000
# 25%      223.500000
# 50%      446.000000
# 75%      668.500000
# max      891.000000
# dtype: float64

# %%
print(f"ID mean is {id_values.mean()} \nMedian is {id_values.median()}")
print(f"ID min is {id_values.min()} \nmax is {id_values.max()}")
# Out:
# ID mean is 446.0
# Median is 446.0
# ID min is 1
# max is 891

# %%
my_newly_copied_dataframe = data

# %%
remove_row = my_newly_copied_dataframe.iloc[random.randint(id_values.min()-1, id_values.max())]
my_newly_copied_dataframe=my_newly_copied_dataframe.drop(random.randint(my_newly_copied_dataframe['PassengerId'].min()-1, my_newly_copied_dataframe['PassengerId'].max()))
my_newly_copied_dataframe.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   890.000000  890.000000  890.000000  ...  890.000000  890.000000  890.000000
# mean    445.792135    0.383146    2.310112  ...    0.523596    0.382022   32.206685
# std     257.423695    0.486427    0.835388  ...    1.103224    0.806409   49.721315
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.250000    0.000000    2.000000  ...    0.000000    0.000000    7.903100
# 50%     445.500000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.750000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
my_newly_copied_dataframe = my_newly_copied_dataframe.append(remove_row)
my_newly_copied_dataframe.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    445.436588    0.383838    2.310887  ...    0.524130    0.382716   32.195631
# std     257.497837    0.486592    0.835238  ...    1.102719    0.806221   49.694469
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     222.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     445.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
sembark_values = data['Embarked']
# nembark_values = np.asarray(sembark_values)
# embark_values = pd.Series(nembark_values)
print(type(sembark_values))
# Out:
# <class 'pandas.core.series.Series'>

# %%
isembark = pd.notnull(sembark_values)

# %%
isembark.sum()
# Out:
# 889

# %%
sembark_values = sembark_values.isnull() # better

# %%
data[ data['PassengerId'] > 880 ]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 880          881         1       2  ...  26.0000   NaN         S
# 881          882         0       3  ...   7.8958   NaN         S
# 882          883         0       3  ...  10.5167   NaN         S
# 883          884         0       2  ...  10.5000   NaN         S
# 884          885         0       3  ...   7.0500   NaN         S
# 885          886         0       3  ...  29.1250   NaN         Q
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [11 rows x 12 columns]

# %%
data[sembark_values]
# Out:
#      PassengerId  Survived  Pclass  ...  Fare Cabin  Embarked
# 61            62         1       1  ...  80.0   B28       NaN
# 829          830         1       1  ...  80.0   B28       NaN
#
# [2 rows x 12 columns]

# %%
data = data.dropna(subset=['Embarked']) #remove embarked nans

# %%
data = data.dropna() #remove nans fillna for changing a row

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   183.000000  183.000000  183.000000  ...  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257  ...    0.464481    0.475410   78.682469
# std     247.052476    0.470725    0.515187  ...    0.644159    0.754617   76.347843
# min       2.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     263.500000    0.000000    1.000000  ...    0.000000    0.000000   29.700000
# 50%     457.000000    1.000000    1.000000  ...    0.000000    0.000000   57.000000
# 75%     676.000000    1.000000    1.000000  ...    1.000000    1.000000   90.000000
# max     890.000000    1.000000    3.000000  ...    3.000000    4.000000  512.329200
#
# [8 rows x 7 columns]

# %%
sembark_values.unique()
# Out:
# array([False,  True])

# %%
sembark_values.fillna("True")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Embarked, Length: 891, dtype: bool

# %%
data.fillna("True")
# Out:
#      PassengerId  Survived  Pclass  ...     Fare        Cabin  Embarked
# 1              2         1       1  ...  71.2833          C85         C
# 3              4         1       1  ...  53.1000         C123         S
# 6              7         0       1  ...  51.8625          E46         S
# 10            11         1       3  ...  16.7000           G6         S
# 11            12         1       1  ...  26.5500         C103         S
# ..           ...       ...     ...  ...      ...          ...       ...
# 871          872         1       1  ...  52.5542          D35         S
# 872          873         0       1  ...   5.0000  B51 B53 B55         S
# 879          880         1       1  ...  83.1583          C50         C
# 887          888         1       1  ...  30.0000          B42         S
# 889          890         1       1  ...  30.0000         C148         C
#
# [183 rows x 12 columns]

# %%
sns.distplot(data['Age'])
# Out:
# <div id='96aa8c99-5003-4c29-9787-e658b8bb0ec8'></div>
# <div id='219296ae-7cd5-4a0b-b234-2f412be0f6f5'></div>

# %%
sns.catplot(x="Embarked",y="Age",data=data)
# Out:
# <div id='ddb8b006-0576-4970-9697-5b7a706204db'></div>
# <div id='ed3134bb-d8c1-4538-8906-a9a8b5f11448'></div>

# %%
sns.catplot(x="Embarked",y="Age",data=data)
# Out:
# <div id='af9c8d01-fe7c-46af-b45d-e6c24301d94c'></div>
# <div id='36b61ce2-b6f0-46da-a01a-d1a38a38fc59'></div>

# %%
sns.boxplot(x="Embarked",y="Age",data=data)
# Out:
# <div id='f18c9afc-e850-4f0f-b2c4-b6c1bea06e8b'></div>
# <div id='5a0aac4c-2622-4a36-bcd2-8cce789eb787'></div>

# %%
sns.boxplot(x="Sex",y="Fare",hue="Pclass",data=data)
# Out:
# <div id='35b68537-7e73-43cb-bfa0-005983952551'></div>
# <div id='62178e2b-c48d-43c0-9d48-9ee9bc3bd6d2'></div>

# %%
sns.boxplot(x="Pclass",y="Fare",hue="Sex",data=data)
# Out:
# <div id='daa4f896-eb35-451a-8388-2fb12f3f3894'></div>
# <div id='233a9c9b-2d5e-4a5f-97d5-cddaede1a5d7'></div>

# %%
tips = sns.load_dataset('tips')

# %%
sns.heatmap(tips.corr(),annot=True)
# Out:
# <div id='3410a703-956c-4a27-bfe6-d7566be3f7b4'></div>
# <div id='b4d0ffbb-614a-465f-868e-63fbe8eae051'></div>

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.pairplot(tips)
# Out:
# <div id='b543475a-b83c-4400-b1ec-b5087301789b'></div>
# <div id='80313d64-ad42-4454-9aa8-eddce7e7913a'></div>

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips) # reg plot for line
# Out:
# <div id='3d6ac6b5-ea16-4ba7-820b-e6a3b6a14eea'></div>
# <div id='748f5da2-2333-4b7c-8f5f-f424c8f62288'></div>
